# %% [markdown]
# # 10989: 수 정렬하기 3
# ## 문제
# N개의 수가 주어졌을 때, 이를 오름차순으로 정렬하는 프로그램을 작성하시오.
#
# ## 입력
# 첫째 줄에 수의 개수 N(1 ≤ N ≤ 10,000,000)이 주어진다. 둘째 줄부터 N개의 줄에는 수가 주어진다. 이 수는 10,000보다 작거나 같은 자연수이다.
#
# ## 출력
# 첫째 줄부터 N개의 줄에 오름차순으로 정렬한 결과를 한 줄에 하나씩 출력한다.
#
# ## 예제 입력 1
# ```
# 10
# 5
# 2
# 3
# 1
# 4
# 2
# 3
# 5
# 1
# 7
# ```
#
# ## 예제 출력 1
# ```
# 1
# 1
# 2
# 2
# 3
# 3
# 4
# 5
# 5
# 7
# ```

# %%
# 다른 사람의 정답 코드
# 출처: https://velog.io/@klaus/%ED%8C%8C%EC%9D%B4%EC%8D%ACPython-%EB%B0%B1%EC%A4%80-10989%EB%B2%88-%EC%88%98-%EC%A0%95%EB%A0%AC%ED%95%98%EA%B8%B0-3

import sys
input = sys.stdin.readline

n = int(input())

# 10001 크기의 리스트 정의
count = [0] * 10001

# n개의 정수를 받으며 즉시 count 리스트에 반영
for _ in range(n):
    num = int(input())
    count[num] += 1

# count 리스트에 접근해서 정렬된 수 출력
for i in range(10001):
    for j in range(count[i]):
        print(i)

# %%
# 내가 작성한 코드: 제출 시 메모리 초과 발생 
import sys

### 백준 제출 시 제거할 코드
import io
input_data = """10
5
2
3
1
4
2
3
5
1
7"""
sys.stdin = io.StringIO(input_data)
### 까지
input = sys.stdin.readline

# 입력 읽기
n = int(input())

array = []

for _ in range(n):
    array.append(int(input()))

# 계수 정렬 실시
# count = [0] * (max(array) + 1)
count = [0] * (10000 + 1)

for i in range(len(array)):
    count[array[i]] += 1

for i in range(0, len(count)): 
    for j in range(count[i]):
        print(i)
# Out:
# 1
# 1
# 2
# 2
# 3
# 3
# 4
# 5
# 5
# 7
